# %% [markdown]
# # Sales Analysis
#
# Quarterly revenue by region.

# %%
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
# volatile table

# %% [raw]
# Generated by an external reporting tool.
